# %%
import customers

#data = json.loads(customers.CUSTOMERS)

for customer in customers.CUSTOMERS:
    print(customer["customerId"])
# Out:
# CUST_144644
# CUST_641358
# CUST_431216
# CUST_413026
# CUST_508699
# CUST_245739
# CUST_124112
# CUST_537952
# CUST_882222
# CUST_882196
# CUST_447096
# CUST_819217
# CUST_300299
# CUST_531527
# CUST_592021
# CUST_702693
# CUST_940182
# CUST_354014
# CUST_983007
# CUST_870417
# CUST_536081
# CUST_396296
# CUST_688100
# CUST_582305
# CUST_869113
# CUST_136944
# CUST_475118
# CUST_335101
# CUST_329681
# CUST_196402
# CUST_245692
# CUST_741878
# CUST_580128
# CUST_378552
# CUST_857434
# CUST_395370
# CUST_907506
# CUST_211489
# CUST_117688
# CUST_539056
# CUST_992912
# CUST_138103
# CUST_615872
# CUST_696651
# CUST_225730
# CUST_646839
# CUST_787451
# CUST_286747
# CUST_976825
# CUST_282634

# %%
import customers

def customer_exists(customerId):
    return any(c["customerId"] == customerId for c in customers.CUSTOMERS)

# %%
print(customer_exists("CUST_641358"))
# Out:
# True

# %%
print(customer_exists("CUST_665757"))
# Out:
# False
